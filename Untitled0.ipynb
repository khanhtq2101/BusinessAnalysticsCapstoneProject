# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append("/content/drive/MyDrive/Introduction to Business Analytics")

# %%
from eda import correlation

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.4/281.4 MB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 19.4 MB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845512 sha256=c09cf906bacc70dfab8b1a3ffeec35173ef3f1955914f3c22698741b0c648e2e
#   Stored in directory: /root/.cache/pip/wheels/43/dc/11/ec201cd671da62fa9c5cc77078235e40722170ceba231d7598
# Successfully built pyspark
# ...

# %%
# !python /content/drive/MyDrive/Introduction\ to\ Business\ Analytics/eda.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Introduction to Business Analytics/eda.py", line 6, in <module>
#     import pyspark
# ModuleNotFoundError: No module named 'pyspark'

# %%
# !ls /content/drive/MyDrive/Introduction\ to\ Business\ Analytics
# Out:
#  eda.py				    Untitled0.ipynb
# 'Explanatory Data Analysis.ipynb'   WA_Fn-UseC_-HR-Employee-Attrition.csv
